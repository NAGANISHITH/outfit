# %%
 ! pip install skin-tone-classifier --upgrade
# Out:
# Requirement already satisfied: skin-tone-classifier in /usr/local/lib/python3.12/dist-packages (1.2.6)
# Requirement already satisfied: opencv-python>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from skin-tone-classifier) (4.12.0.88)
# Requirement already satisfied: numpy>=1.21.5 in /usr/local/lib/python3.12/dist-packages (from skin-tone-classifier) (2.0.2)
# Requirement already satisfied: colormath>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from skin-tone-classifier) (3.0.0)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.12/dist-packages (from skin-tone-classifier) (4.67.1)
# Requirement already satisfied: colorama>=0.4.6 in /usr/local/lib/python3.12/dist-packages (from skin-tone-classifier) (0.4.6)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.12/dist-packages (from skin-tone-classifier) (25.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from skin-tone-classifier) (2.32.4)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.12/dist-packages (from colormath>=3.0.0->skin-tone-classifier) (3.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->skin-tone-classifier) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->skin-tone-classifier) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->skin-tone-classifier) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->skin-tone-classifier) (2025.8.3)

# %%
! stone -v
# Out:
# stone 1.2.6

# %%
import stone

from google.colab.patches import cv2_imshow

# %%
image_path = "/content/02a.jpg"

# %%
result = stone.process(image_path, image_type="color", return_report_image=True)

# %%
report_images = result.pop("report_images")  # obtain and remove the report image from the `result`

face_id = 1
cv2_imshow(report_images[face_id]) # Use `stone.show` instead in Python scripts
# Out:
# <PIL.Image.Image image mode=RGB size=450x378>

# %%
# convert the result to json
from json import dumps

result_json = dumps(result)
result_json
# Out:
# '{"basename": "02a", "extension": ".jpg", "image_type": "color", "faces": [{"dominant_colors": [{"color": "#674A36", "percent": "0.56"}, {"color": "#9E7962", "percent": "0.44"}], "skin_tone": "#6F503C", "tone_label": "CD", "accuracy": 91.49, "face_id": 1}]}'

# %%
! stone -i /content/02a.jpg --debug
# Out:
# The program is processing your images...
# Please wait for the program to finish.
# Processing 02a: 100% 1/1 [00:00<00:00,  4.57images/s, Image Type=bw, #Faces=1, Face ID=1, Skin Tone=#707070, Label=BJ, Accuracy=82.7]

# %%
# !ls
# Out:
# 02a.jpg  debug	log  result_bak_2509180618.csv	result.csv  sample_data

# %%
from IPython.display import Image
Image('/content/debug/bw/faces_1/02a-1.jpg')

# %%
import pandas as pd

pd.read_csv("./result.csv")
# Out:
#       file image type  face id dominant 1  percent 1 dominant 2  percent 2  \
# 0  02a.jpg         bw        1    #6C4F3A       0.61    #A38D7B       0.39
#
#   skin tone tone label  accuracy(0-100)
# 0   #707070         BJ            82.65
